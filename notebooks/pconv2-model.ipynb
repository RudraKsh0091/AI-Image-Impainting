# %%
# !git clone https://github.com/RudraKsh0091/AI-Image-Impainting.git
# %cd AI-Image-Impainting
# !pip install -r requirements.txt
# Out:
# Cloning into 'AI-Image-Impainting'...
# remote: Enumerating objects: 166, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 166 (delta 92), reused 100 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (166/166), 2.21 MiB | 13.31 MiB/s, done.
# Resolving deltas: 100% (92/92), done.
# Filtering content: 100% (3/3), 974.75 MiB | 35.10 MiB/s, done.
# /kaggle/working/AI-Image-Impainting
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python->-r requirements.txt (line 1)) (2.4.6)

# %%
# !python -m src.train
# Out:
# 2026-06-22 06:19:31.609271: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1782109171.801193     158 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1782109171.859594     158 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1782109172.324318     158 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782109172.324376     158 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782109172.324388     158 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782109172.324396     158 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# I0000 00:00:1782109188.776811     158 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1782109188.782736     158 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:643: UserWarning: A total of 6 objects could not be loaded. Example error message for object <Conv2D name=block1_conv1, built=True>:
#
# Layer 'block1_conv1' expected 2 variables, but received 0 variables during loading. Expected: ['kernel', 'bias']
#
# List of objects that could not be loaded:
# [<Conv2D name=block1_conv1, built=True>, <Conv2D name=block1_conv2, built=True>, <Conv2D name=block2_conv1, built=True>, <Conv2D name=block2_conv2, built=True>, <Conv2D name=block3_conv1, built=True>, <Conv2D name=block3_conv2, built=True>]
#   warnings.warn(msg)
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782109205.416550     189 service.cc:152] XLA service 0x78eba000a2f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1782109205.416617     189 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1782109205.416628     189 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1782109207.207477     189 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-06-22 06:20:13.390669: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng12{k11=2} for conv %cudnn-conv-bias-activation.56 = (f32[16,256,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,768,32,32]{3,2,1,0} %bitcast.21549, f32[256,768,3,3]{3,2,1,0} %bitcast.17284, f32[256]{0} %bitcast.21609), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="inpainting_model_1/conv2d_14_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-22 06:20:13.479507: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.088968344s
# Trying algorithm eng12{k11=2} for conv %cudnn-conv-bias-activation.56 = (f32[16,256,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,768,32,32]{3,2,1,0} %bitcast.21549, f32[256,768,3,3]{3,2,1,0} %bitcast.17284, f32[256]{0} %bitcast.21609), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="inpainting_model_1/conv2d_14_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-22 06:20:30.862113: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:31.166448: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:32.962577: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:33.191837: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:35.447227: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:35.766026: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.25 = (f32[16,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,128,128]{3,2,1,0} %bitcast.18418, f32[128,128,3,3]{3,2,1,0} %bitcast.17794), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_3/block2_conv2_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-22 06:20:35.849589: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:35.866924: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.101013656s
# Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.25 = (f32[16,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,128,128]{3,2,1,0} %bitcast.18418, f32[128,128,3,3]{3,2,1,0} %bitcast.17794), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_3/block2_conv2_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-22 06:20:37.196032: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:37.537160: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:41.917989: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:42.280201: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.36 = (f32[16,192,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,128,128]{3,2,1,0} %bitcast.22065, f32[64,192,3,3]{3,2,1,0} %bitcast.17462), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/inpainting_model_1/conv2d_16_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-22 06:20:42.312574: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:42.337767: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.05770405s
# Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.36 = (f32[16,192,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,128,128]{3,2,1,0} %bitcast.22065, f32[64,192,3,3]{3,2,1,0} %bitcast.17462), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/inpainting_model_1/conv2d_16_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-22 06:20:43.359839: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:43.627498: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:51.774366: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 06:20:52.002213: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1782109267.623037     189 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1616s 685ms/step - loss: 9879.0713 - val_loss: 8923.9961
# Epoch 2/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1513s 671ms/step - loss: 9467.0732 - val_loss: 8411.5342
# Epoch 3/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1514s 671ms/step - loss: 9125.1211 - val_loss: 8145.1265
# Epoch 4/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1512s 670ms/step - loss: 9025.2529 - val_loss: 8738.3369
# Epoch 5/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1515s 672ms/step - loss: 8846.1953 - val_loss: 8696.7617
# Epoch 6/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1516s 672ms/step - loss: 8805.1553 - val_loss: 8499.0449
# Epoch 7/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1514s 671ms/step - loss: 8735.7344 - val_loss: 8158.7529
# Epoch 8/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1514s 672ms/step - loss: 8922.1631 - val_loss: 7932.6953
# Epoch 9/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1515s 672ms/step - loss: 8575.0391 - val_loss: 7933.4243
# Epoch 10/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1515s 672ms/step - loss: 8584.4639 - val_loss: 7939.8560
# Epoch 11/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1514s 672ms/step - loss: 8566.8740 - val_loss: 8074.0488
# Epoch 12/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1515s 672ms/step - loss: 8581.4023 - val_loss: 8621.4639
# Epoch 13/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 1512s 671ms/step - loss: 8449.9316 - val_loss: 8302.7461
