# %%
# !git clone https://github.com/RudraKsh0091/AI-Image-Impainting.git
# %cd AI-Image-Impainting
# !pip install -r requirements.txt
# Out:
# Cloning into 'AI-Image-Impainting'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 85 (delta 47), reused 38 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (85/85), 15.88 KiB | 15.88 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# /kaggle/working/AI-Image-Impainting/AI-Image-Impainting
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.19.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (4.13.0.92)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (26.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (1.80.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (3.16.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 1)) (0.46.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 1)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 1)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 1)) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 1)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 1)) (2026.2.25)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 1)) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 1)) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->-r requirements.txt (line 1)) (0.1.2)

# %%
# !python -m src.train
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781941624.282884     142 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781941624.350653     142 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781941624.843981     142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781941624.844049     142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781941624.844056     142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781941624.844067     142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# I0000 00:00:1781941641.910222     142 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1781941641.916207     142 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781941655.351490     172 service.cc:152] XLA service 0x78f15800bba0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781941655.351531     172 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1781941655.351544     172 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1781941656.530565     172 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1781941681.522256     172 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 710s 299ms/step - loss: 0.0696 - val_loss: 0.0489
# Epoch 2/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 630s 278ms/step - loss: 0.0457 - val_loss: 0.0430
# Epoch 3/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 631s 279ms/step - loss: 0.0409 - val_loss: 0.0507
# Epoch 4/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 631s 279ms/step - loss: 0.0378 - val_loss: 0.0522
# Epoch 5/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 650s 287ms/step - loss: 0.0360 - val_loss: 0.0347
# Epoch 6/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 639s 282ms/step - loss: 0.0341 - val_loss: 0.0344
# Epoch 7/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 654s 289ms/step - loss: 0.0331 - val_loss: 0.0345
# Epoch 8/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 660s 291ms/step - loss: 0.0321 - val_loss: 0.0311
# Epoch 9/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 636s 281ms/step - loss: 0.0313 - val_loss: 0.0313
# Epoch 10/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 643s 284ms/step - loss: 0.0305 - val_loss: 0.0300
# Epoch 11/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 651s 288ms/step - loss: 0.0299 - val_loss: 0.0287
# Epoch 12/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 652s 288ms/step - loss: 0.0293 - val_loss: 0.0284
# Epoch 13/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 650s 287ms/step - loss: 0.0288 - val_loss: 0.0285
# Epoch 14/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 653s 288ms/step - loss: 0.0283 - val_loss: 0.0283
# Epoch 15/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 637s 281ms/step - loss: 0.0278 - val_loss: 0.0277
# Epoch 16/30
# 1114/2250 ━━━━━━━━━━━━━━━━━━━━ 5:09 272ms/step - loss: 0.0277
