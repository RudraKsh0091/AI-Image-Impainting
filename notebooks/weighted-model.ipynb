# %%
# !git clone https://github.com/RudraKsh0091/AI-Image-Impainting.git
# %cd AI-Image-Impainting
# !pip install -r requirements.txt
# Out:
# Cloning into 'AI-Image-Impainting'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 120 (delta 61), reused 70 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 1.11 MiB | 18.56 MiB/s, done.
# Resolving deltas: 100% (61/61), done.
# /kaggle/working/AI-Image-Impainting
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python->-r requirements.txt (line 1)) (2.4.6)

# %%
# !python -m src.train
# Out:
# 2026-06-21 04:43:04.362346: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1782016984.579415     159 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1782016984.642953     159 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1782016985.159576     159 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782016985.159631     159 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782016985.159645     159 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782016985.159655     159 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# I0000 00:00:1782017002.591078     159 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1782017002.597316     159 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782017016.769360     188 service.cc:152] XLA service 0x7adf40007e20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1782017016.769415     188 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1782017016.769426     188 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1782017017.962299     188 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-06-21 04:43:45.853946: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-21 04:43:46.159914: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-21 04:43:47.827395: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-21 04:43:48.129403: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-21 04:43:53.819876: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-21 04:43:54.046544: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1782017042.058955     188 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 690s 291ms/step - loss: 0.1181 - val_loss: 0.1266
# Epoch 2/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 600s 265ms/step - loss: 0.1170 - val_loss: 0.1167
# Epoch 3/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 603s 266ms/step - loss: 0.1167 - val_loss: 0.1140
# Epoch 4/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 600s 265ms/step - loss: 0.1162 - val_loss: 0.1143
# Epoch 5/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 601s 266ms/step - loss: 0.1158 - val_loss: 0.1144
# Epoch 6/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 603s 266ms/step - loss: 0.1144 - val_loss: 0.1123
# Epoch 7/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 602s 266ms/step - loss: 0.1136 - val_loss: 0.1197
# Epoch 8/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 611s 270ms/step - loss: 0.1134 - val_loss: 0.1141
# Epoch 9/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 617s 272ms/step - loss: 0.1132 - val_loss: 0.1167
# Epoch 10/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 610s 269ms/step - loss: 0.1133 - val_loss: 0.1108
# Epoch 11/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 614s 271ms/step - loss: 0.1127 - val_loss: 0.1135
# Epoch 12/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 614s 271ms/step - loss: 0.1116 - val_loss: 0.1141
# Epoch 13/30
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - loss: 0.1109
