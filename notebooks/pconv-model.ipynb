# %%
# !git clone https://github.com/RudraKsh0091/AI-Image-Impainting.git
# %cd AI-Image-Impainting
# !pip install -r requirements.txt
# Out:
# Cloning into 'AI-Image-Impainting'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 143 (delta 77), reused 80 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (143/143), 1.11 MiB | 14.02 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# Filtering content: 100% (2/2), 669.81 MiB | 28.01 MiB/s, done.
# /kaggle/working/AI-Image-Impainting
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python->-r requirements.txt (line 1)) (2.4.6)

# %%
# !python -m src.train
# Out:
# 2026-06-21 10:43:00.332051: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1782038580.663853     160 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1782038580.736793     160 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1782038581.683394     160 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782038581.683452     160 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782038581.683456     160 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782038581.683460     160 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# I0000 00:00:1782038600.984963     160 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1782038600.991353     160 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782038616.514882     191 service.cc:152] XLA service 0x7a126800a710 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1782038616.514948     191 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1782038616.514960     191 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1782038617.814747     191 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-06-21 10:43:44.114872: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng12{k11=2} for conv %cudnn-conv-bias-activation.20 = (f32[16,256,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,768,32,32]{3,2,1,0} %bitcast.18132, f32[256,768,3,3]{3,2,1,0} %bitcast.14960, f32[256]{0} %bitcast.18192), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="inpainting_model_1/conv2d_14_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-21 10:43:44.312448: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.19769426s
# Trying algorithm eng12{k11=2} for conv %cudnn-conv-bias-activation.20 = (f32[16,256,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,768,32,32]{3,2,1,0} %bitcast.18132, f32[256,768,3,3]{3,2,1,0} %bitcast.14960, f32[256]{0} %bitcast.18192), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="inpainting_model_1/conv2d_14_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-21 10:43:49.858240: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-21 10:43:50.201939: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.12 = (f32[16,192,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,128,128]{3,2,1,0} %bitcast.18648, f32[64,192,3,3]{3,2,1,0} %bitcast.15138), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/inpainting_model_1/conv2d_16_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-21 10:43:50.248201: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-21 10:43:50.273376: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.071547361s
# Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.12 = (f32[16,192,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,128,128]{3,2,1,0} %bitcast.18648, f32[64,192,3,3]{3,2,1,0} %bitcast.15138), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape